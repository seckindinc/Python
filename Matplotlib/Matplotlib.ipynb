# %%
#Loading library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Gathering Data
credit = pd.read_csv(r"/home/seckindinc/Desktop/Github/Python/Data-Sets/Risk.txt",sep=",",index_col=False)

# %%
#Simple plot
plt.figure(figsize=(8,6), dpi=80)
plt.plot(credit['AGE'],color='gray',linewidth=0.2)

# %%
#Scatter plot
plt.plot('AGE', 'INCOME', data=credit, linestyle='none', marker='o')

# %%
#Bubble plot
plt.scatter(credit['AGE'], credit['NUMCARDS'], alpha=0.1)
plt.figure()
plt.scatter(credit['AGE'], credit['NUMCARDS'], alpha=0.8)
plt.figure()
plt.scatter(credit['AGE'], credit['NUMCARDS'], alpha=0.1,marker='+')

# %%
#Creating Time Based Graph
data2 = data[data['X'] == '105.1.12.18'][['Y','Z']]
data3 = data2[data2['X'].str[-2:] == '00']
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
plt.xticks(rotation=90)
plt.bar(data3['Y'],data3['Z'])
