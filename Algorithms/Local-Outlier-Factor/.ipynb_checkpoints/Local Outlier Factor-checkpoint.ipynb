# %% [markdown]
# ## Local Outlier Factor

# %% [markdown]
# This example presents the Local Outlier Factor (LOF) estimator. The LOF algorithm is an unsupervised outlier detection method which computes the local density deviation of a given data point with respect to its neighbors. It considers as outlier samples that have a substantially lower density than their neighbors.
#
# The number of neighbors considered, (parameter n_neighbors) is typically chosen 1) greater than the minimum number of objects a cluster has to contain, so that other objects can be local outliers relative to this cluster, and 2) smaller than the maximum number of close by objects that can potentially be local outliers. In practice, such informations are generally not available, and taking n_neighbors=20 appears to work well in general.
#
# ![image.png](attachment:image.png)

# %%
#Loading Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings; warnings.simplefilter('ignore')
# %matplotlib inline

# %%
#Gathering Data
credit = pd.read_csv(r"E:\Github\Python\Risk.txt",sep=",",index_col=False)

# %%
#First 5 Rows of Data
credit.head()
# Out:
#        ID  AGE  INCOME GENDER    MARITAL  NUMKIDS  NUMCARDS  HOWPAID MORTGAGE  \
# 0  100756   44   59944      m  married          1         2  monthly        y
# 1  100668   35   59692      m  married          1         1  monthly        y
# 2  100418   34   59508      m  married          1         1  monthly        y
# 3  100416   34   59463      m  married          0         2  monthly        y
# 4  100590   39   59393      f  married          0         2  monthly        y
#
#    STORECAR  LOANS        RISK
# 0         2      0  good risk
# 1         1      0  bad loss
# 2         2      1  good risk
# 3         1      1  bad loss
# 4         1      0  good risk

# %%
#Selecting Numeric Fields To Be Used In Modelling
X = credit[['AGE','INCOME','NUMKIDS','NUMCARDS','LOANS']]

# %%
#Loading Min Max Scaling and Creating New Data Frame
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_normalized = pd.DataFrame(scaler.fit_transform(X))

# %%
#Assining Column Names
X_normalized.columns = ['AGE','INCOME','NUMKIDS','NUMCARDS','LOANS']

# %%
#Implementing Algorithm
from sklearn.neighbors import LocalOutlierFactor
clf = LocalOutlierFactor()
clf.fit(X_normalized)
# Out:
# LocalOutlierFactor(algorithm='auto', contamination=0.1, leaf_size=30,
#           metric='minkowski', metric_params=None, n_jobs=1, n_neighbors=20,
#           p=2)

# %%
#Predicting Anomaly Class and Anomaly Score
Anomaly_Class = clf.fit_predict(X_normalized)
Anomaly_Score = clf._decision_function(X_normalized)

# %%
#Creating New Columns Based on Anomaly Detection
X['Anomaly_Class'] = Anomaly_Class
X['Anomaly_Score'] = Anomaly_Score

# %%
#Viewing Class Counts
#-1 is anomaly, 1 is normal
X.groupby('Anomaly_Class')[['Anomaly_Score']].count()
# Out:
#                Anomaly_Score
# Anomaly_Class
# -1                       412
#  1                      3705

# %%
#Histogram of Anomaly Scores By Anomaly Class
X['Anomaly_Score'].hist(by=X['Anomaly_Class'])
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001E880095978>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001E8800D3B70>], dtype=object)

# %%
#Descriptive Statistics
X['Anomaly_Score'].describe()
# Out:
# count    4117.000000
# mean       -1.059338
# std         0.127196
# min        -2.877914
# 25%        -1.087398
# 50%        -1.025744
# 75%        -0.989208
# max        -0.923330
# Name: Anomaly_Score, dtype: float64

# %%
#Implementing Algorithm With Different Parameters
from sklearn.neighbors import LocalOutlierFactor
clf = LocalOutlierFactor(n_neighbors=50)
clf.fit(X_normalized)
# Out:
# LocalOutlierFactor(algorithm='auto', contamination=0.1, leaf_size=30,
#           metric='minkowski', metric_params=None, n_jobs=1, n_neighbors=50,
#           p=2)

# %%
#Predicting Anomaly Class and Anomaly Score
Anomaly_Class = clf.fit_predict(X_normalized)
Anomaly_Score = clf._decision_function(X_normalized)

# %%
#Creating New Columns Based on Anomaly Detection
X['Anomaly_Class_neighbors_50'] = Anomaly_Class
X['Anomaly_Score_neighbors_50'] = Anomaly_Score

# %%
#Viewing Class Counts
#-1 is anomaly, 1 is normal
X.groupby('Anomaly_Class_neighbors_50')[['Anomaly_Score_neighbors_50']].count()
# Out:
#                             Anomaly_Score_neighbors_50
# Anomaly_Class_neighbors_50
# -1                                                 412
#  1                                                3705

# %%
#Histogram of Anomaly Scores By Anomaly Class
X['Anomaly_Score_neighbors_50'].hist(by=X['Anomaly_Class_neighbors_50'])
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001E88012BC18>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001E88019BF60>], dtype=object)

# %%
#Descriptive Statistics
X['Anomaly_Score_neighbors_50'].describe()
# Out:
# count    4117.000000
# mean       -1.050253
# std         0.102863
# min        -2.604335
# 25%        -1.081311
# 50%        -1.017581
# 75%        -0.987330
# max        -0.925500
# Name: Anomaly_Score_neighbors_50, dtype: float64

# %%
#Implementing Algorithm With Different Parameters
from sklearn.neighbors import LocalOutlierFactor
clf = LocalOutlierFactor(n_neighbors=5)
clf.fit(X_normalized)
# Out:
# LocalOutlierFactor(algorithm='auto', contamination=0.1, leaf_size=30,
#           metric='minkowski', metric_params=None, n_jobs=1, n_neighbors=5,
#           p=2)

# %%
#Predicting Anomaly Class and Anomaly Score
Anomaly_Class = clf.fit_predict(X_normalized)
Anomaly_Score = clf._decision_function(X_normalized)

# %%
#Creating New Columns Based on Anomaly Detection
X['Anomaly_Class_neighbors_5'] = Anomaly_Class
X['Anomaly_Score_neighbors_5'] = Anomaly_Score

# %%
#Viewing Class Counts
#-1 is anomaly, 1 is normal
X.groupby('Anomaly_Class_neighbors_5')[['Anomaly_Score_neighbors_5']].count()
# Out:
#                            Anomaly_Score_neighbors_5
# Anomaly_Class_neighbors_5
# -1                                               412
#  1                                              3705

# %%
#Histogram of Anomaly Scores By Anomaly Class
X['Anomaly_Score_neighbors_5'].hist(by=X['Anomaly_Class_neighbors_5'])
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001E880238F60>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001E88026EDD8>], dtype=object)

# %%
#Descriptive Statistics
X['Anomaly_Score_neighbors_5'].describe()
# Out:
# count    4117.000000
# mean       -1.059918
# std         0.189450
# min        -3.864758
# 25%        -1.068884
# 50%        -1.005649
# 75%        -0.976114
# max        -0.860922
# Name: Anomaly_Score_neighbors_5, dtype: float64

# %%
#Implementing Algorithm
from sklearn.neighbors import LocalOutlierFactor
clf = LocalOutlierFactor(algorithm='ball_tree')
clf.fit(X_normalized)
# Out:
# LocalOutlierFactor(algorithm='ball_tree', contamination=0.1, leaf_size=30,
#           metric='minkowski', metric_params=None, n_jobs=1, n_neighbors=20,
#           p=2)

# %%
#Predicting Anomaly Class and Anomaly Score
Anomaly_Class = clf.fit_predict(X_normalized)
Anomaly_Score = clf._decision_function(X_normalized)

# %%
#Creating New Columns Based on Anomaly Detection
X['Anomaly_Class_ball_tree'] = Anomaly_Class
X['Anomaly_Score_ball_tree'] = Anomaly_Score

# %%
#Viewing Class Counts
#-1 is anomaly, 1 is normal
X.groupby('Anomaly_Class_ball_tree')[['Anomaly_Score_ball_tree']].count()
# Out:
#                          Anomaly_Score_ball_tree
# Anomaly_Class_ball_tree
# -1                                           412
#  1                                          3705

# %%
#Histogram of Anomaly Scores By Anomaly Class
X['Anomaly_Score_ball_tree'].hist(by=X['Anomaly_Class_ball_tree'])
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001E880218748>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001E88034F588>], dtype=object)

# %%
#Descriptive Statistics
X['Anomaly_Score_ball_tree'].describe()
# Out:
# count    4117.000000
# mean       -1.059332
# std         0.127199
# min        -2.877914
# 25%        -1.087398
# 50%        -1.025744
# 75%        -0.989208
# max        -0.923330
# Name: Anomaly_Score_ball_tree, dtype: float64

# %%
#Implementing Algorithm
from sklearn.neighbors import LocalOutlierFactor
clf = LocalOutlierFactor(algorithm='kd_tree')
clf.fit(X_normalized)
# Out:
# LocalOutlierFactor(algorithm='kd_tree', contamination=0.1, leaf_size=30,
#           metric='minkowski', metric_params=None, n_jobs=1, n_neighbors=20,
#           p=2)

# %%
#Predicting Anomaly Class and Anomaly Score
Anomaly_Class = clf.fit_predict(X_normalized)
Anomaly_Score = clf._decision_function(X_normalized)

# %%
#Creating New Columns Based on Anomaly Detection
X['Anomaly_Class_kd_tree'] = Anomaly_Class
X['Anomaly_Score_kd_tree'] = Anomaly_Score

# %%
#Viewing Class Counts
#-1 is anomaly, 1 is normal
X.groupby('Anomaly_Class_kd_tree')[['Anomaly_Score_kd_tree']].count()
# Out:
#                        Anomaly_Score_kd_tree
# Anomaly_Class_kd_tree
# -1                                       412
#  1                                      3705

# %%
#Histogram of Anomaly Scores By Anomaly Class
X['Anomaly_Score_kd_tree'].hist(by=X['Anomaly_Class_kd_tree'])
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001E8803BBD30>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001E88041F0B8>], dtype=object)

# %%
#Descriptive Statistics
X['Anomaly_Score_kd_tree'].describe()
# Out:
# count    4117.000000
# mean       -1.059338
# std         0.127196
# min        -2.877914
# 25%        -1.087398
# 50%        -1.025744
# 75%        -0.989208
# max        -0.923330
# Name: Anomaly_Score_kd_tree, dtype: float64

# %%
#Implementing Algorithm
from sklearn.neighbors import LocalOutlierFactor
clf = LocalOutlierFactor(algorithm='brute')
clf.fit(X_normalized)
# Out:
# LocalOutlierFactor(algorithm='brute', contamination=0.1, leaf_size=30,
#           metric='minkowski', metric_params=None, n_jobs=1, n_neighbors=20,
#           p=2)

# %%
#Predicting Anomaly Class and Anomaly Score
Anomaly_Class = clf.fit_predict(X_normalized)
Anomaly_Score = clf._decision_function(X_normalized)

# %%
#Creating New Columns Based on Anomaly Detection
X['Anomaly_Class_brute'] = Anomaly_Class
X['Anomaly_Score_brute'] = Anomaly_Score

# %%
#Viewing Class Counts
#-1 is anomaly, 1 is normal
X.groupby('Anomaly_Class_brute')[['Anomaly_Score_brute']].count()
# Out:
#                      Anomaly_Score_brute
# Anomaly_Class_brute
# -1                                   412
#  1                                  3705

# %%
#Histogram of Anomaly Scores By Anomaly Class
X['Anomaly_Score_brute'].hist(by=X['Anomaly_Class_brute'])
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001E88041FEF0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001E8804EAB38>], dtype=object)

# %%
#Descriptive Statistics
X['Anomaly_Score_brute'].describe()
# Out:
# count    4117.000000
# mean       -1.059327
# std         0.127202
# min        -2.877914
# 25%        -1.087398
# 50%        -1.025744
# 75%        -0.989197
# max        -0.923330
# Name: Anomaly_Score_brute, dtype: float64
