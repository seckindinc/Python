# %%
import sys
import logging

import numpy as np
import scipy as sp
import sklearn
import pandas as pd
import statsmodels.api as sm
from sklearn.metrics import classification_report

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import seaborn as sn
sn.set_context("poster")
sn.set(rc={'figure.figsize': (16, 9.)})
sn.set_style("whitegrid")

import pandas as pd
pd.set_option("display.max_rows", 120)
pd.set_option("display.max_columns", 120)

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('../Data-Sets/Iris.csv')

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.drop(['Id'],inplace = True, axis = 1)

# %%
data.shape
# Out:
# (150, 5)

# %%
data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sn.pairplot(data[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']])

# %%
data.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sn.violinplot( x=data["Species"], y=data["SepalLengthCm"])
plt.subplot(2,2,2)
sn.violinplot( x=data["Species"], y=data["SepalWidthCm"])
plt.subplot(2,2,3)
sn.violinplot( x=data["Species"], y=data["PetalLengthCm"])
plt.subplot(2,2,4)
sn.violinplot( x=data["Species"], y=data["PetalWidthCm"])

# %%
plt.figure(figsize=(7,4)) 
sn.heatmap(data.corr(),annot=True) 
plt.show()

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(data, test_size = 0.25)
X_train = train[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
X_test = test[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
y_train = train['Species']
y_test = test['Species']

# %%
from sklearn import metrics

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier(n_neighbors=3) 
model.fit(X_train,y_train)
prediction_train=model.predict(X_train)
prediction_test=model.predict(X_test)
print('The accuracy of the KNN on train is',metrics.accuracy_score(prediction_train,y_train))
print('The accuracy of the KNN on test is',metrics.accuracy_score(prediction_test,y_test))
# Out:
# The accuracy of the KNN on train is 0.9642857142857143
# The accuracy of the KNN on test is 0.9473684210526315

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression(multi_class='auto') 
model.fit(X_train,y_train)
prediction_train=model.predict(X_train)
prediction_test=model.predict(X_test)
print('The accuracy of the Logistic on train is',metrics.accuracy_score(prediction_train,y_train))
print('The accuracy of the Logistic on test is',metrics.accuracy_score(prediction_test,y_test))
# Out:
# The accuracy of the Logistic on train is 0.9553571428571429
# The accuracy of the Logistic on test is 0.9210526315789473

# %%
for i in [0.001,0.01,0.1,1,10,100,1000]:
    model=LogisticRegression(multi_class='auto',C=i) 
    model.fit(X_train,y_train)
    prediction_train=model.predict(X_train)
    prediction_test=model.predict(X_test)
    print('C is: {:.3f}'.format(i))
    print('The accuracy of the Logistic on train is',metrics.accuracy_score(prediction_train,y_train))
    print('The accuracy of the Logistic on test is',metrics.accuracy_score(prediction_test,y_test))
    print('Coefficients chage due to regularization hyperparameter:\n',model.coef_)
    print('')
# Out:
# C is: 0.001
# The accuracy of the Logistic on train is 0.5
# The accuracy of the Logistic on test is 0.6578947368421053
# Coefficients chage due to regularization hyperparameter:
#  [[-0.03938041  0.00700288 -0.08395695 -0.03414282]
#  [-0.03724419 -0.0339086  -0.00332598 -0.00210344]
#  [-0.04707996 -0.04089484  0.01584833  0.01458736]]
#
# C is: 0.010
# The accuracy of the Logistic on train is 0.7232142857142857
# The accuracy of the Logistic on test is 0.7631578947368421
# Coefficients chage due to regularization hyperparameter:
#  [[ 0.01859271  0.20085628 -0.392044   -0.17450417]
#  [-0.07396399 -0.15398406  0.09454073  0.01176858]
#  [-0.16364309 -0.19004406  0.22241649  0.14770991]]
#
# C is: 0.100
# The accuracy of the Logistic on train is 0.9196428571428571
# The accuracy of the Logistic on test is 0.8947368421052632
# Coefficients chage due to regularization hyperparameter:
#  [[ 0.19267125  0.71225754 -1.13568593 -0.50954426]
#  [ 0.01012998 -0.57216276  0.31723221 -0.18981615]
#  [-0.55733177 -0.48699087  0.80952541  0.67915883]]
#
# C is: 1.000
# The accuracy of the Logistic on train is 0.9553571428571429
# The accuracy of the Logistic on test is 0.9210526315789473
# Coefficients chage due to regularization hyperparameter:
#  [[ 0.39035254  1.39323262 -2.14487011 -0.97411784]
#  [ 0.45996889 -1.61989873  0.62566613 -1.4091534 ]
#  [-1.59988384 -1.13492228  2.14779839  2.25912532]]
#
# C is: 10.000
# The accuracy of the Logistic on train is 0.9642857142857143
# The accuracy of the Logistic on test is 0.9473684210526315
# Coefficients chage due to regularization hyperparameter:
#  [[ 0.61584266  2.18647838 -3.34742949 -1.60307263]
#  [ 0.25783647 -2.59588819  1.2249638  -2.79384044]
#  [-2.86997495 -2.27078874  4.115968    4.90630291]]
#
# C is: 100.000
# The accuracy of the Logistic on train is 0.9732142857142857
# The accuracy of the Logistic on test is 0.9736842105263158
# Coefficients chage due to regularization hyperparameter:
#  [[ 0.88410394  3.08363594 -4.78894288 -2.29056172]
#  [-0.1905873  -3.16187944  1.56252264 -3.23509641]
#  [-3.08434065 -3.15766681  5.57335427  8.08898996]]
#
# C is: 1000.000
# The accuracy of the Logistic on train is 0.9642857142857143
# The accuracy of the Logistic on test is 0.9736842105263158
# Coefficients chage due to regularization hyperparameter:
#  [[ 1.21199157  4.06360945 -6.43959545 -3.19157057]
#  [-0.28833062 -3.28605875  1.62624998 -3.30609172]
#  [-2.17307456 -3.65401577  6.79945588 11.72765692]]

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression(multi_class='auto') 
model.fit(X_train,y_train)
prediction_train=model.predict(X_train)
prediction_test=model.predict(X_test)
print('The accuracy of the Logistic on train is',metrics.accuracy_score(prediction_train,y_train))
print('The accuracy of the Logistic on test is',metrics.accuracy_score(prediction_test,y_test))
# Out:
# The accuracy of the Logistic on train is 0.9553571428571429
# The accuracy of the Logistic on test is 0.9210526315789473

# %%
from sklearn.model_selection import cross_val_score, KFold, StratifiedKFold

# %%
cross_val_score(model,X_train,y_train,cv=10)
# Out:
# array([1.        , 1.        , 1.        , 1.        , 1.        ,
#        1.        , 0.90909091, 0.90909091, 0.90909091, 0.77777778])

# %%
print(cross_val_score(model,X_train,y_train,cv=10).mean())
print(cross_val_score(model,X_train,y_train,cv=10).std())
# Out:
# 0.9505050505050505
# 0.0704830506037152

# %%
cross_val_score(model,X_train,y_train,cv=10)
# Out:
# array([1.        , 1.        , 1.        , 1.        , 1.        ,
#        1.        , 0.90909091, 0.90909091, 0.90909091, 0.77777778])

# %%
cross_val_score(model,X_train,y_train,cv=KFold(n_splits=10))
# Out:
# array([1.        , 1.        , 1.        , 1.        , 1.        ,
#        1.        , 0.90909091, 0.90909091, 0.90909091, 0.81818182])

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'C':[0.001, 0.01, 0.1, 1, 10]}

# %%
model=LogisticRegression(multi_class='auto') 
grid_search = GridSearchCV(LogisticRegression(multi_class='auto') , param_grid)

# %%
X_train, X_test, y_train,  y_test = train_test_split(data[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']], data['Species'], random_state = 42, test_size = 0.25)

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='auto',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'C': [0.001, 0.01, 0.1, 1, 10]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
print(grid_search.score(X_train,y_train))
print(grid_search.score(X_test,y_test))
# Out:
# 0.9732142857142857
# 1.0

# %%
print(grid_search.best_params_)
# Out:
# {'C': 10}

# %%
print(grid_search.best_score_)
# Out:
# 0.9464285714285714

# %%
print(grid_search.best_estimator_)
# Out:
# LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='auto',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
results = pd.DataFrame(grid_search.cv_results_)

# %%
results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       0.002164      0.000782         0.000993        0.000417   0.001
# 1       0.001281      0.000013         0.000773        0.000223    0.01
# 2       0.001364      0.000016         0.000605        0.000005     0.1
# 3       0.001479      0.000156         0.000642        0.000036       1
# 4       0.001344      0.000017         0.000599        0.000002      10
#
#          params  split0_test_score  split1_test_score  split2_test_score  \
# 0  {'C': 0.001}           0.342105           0.342105           0.333333
# 1   {'C': 0.01}           0.657895           0.657895           0.638889
# 2    {'C': 0.1}           0.815789           0.763158           0.833333
# 3      {'C': 1}           0.921053           0.894737           0.972222
# 4     {'C': 10}           0.947368           0.921053           0.972222
#
#    mean_test_score  std_test_score  rank_test_score  split0_train_score  \
# 0         0.339286        0.004097                5            0.337838
# 1         0.651786        0.008876                4            0.648649
# 2         0.803571        0.029824                3            0.797297
# 3         0.928571        0.031938                2            0.959459
# 4         0.946429        0.020800                1            0.959459
#
#    split1_train_score  split2_train_score  mean_train_score  std_train_score
# 0            0.337838            0.342105          0.339260         0.002012
# 1            0.648649            0.657895          0.651731         0.004359
# 2            0.824324            0.789474          0.803698         0.014930
# 3            0.959459            0.934211          0.951043         0.011902
# 4            0.986486            0.960526          0.968824         0.012497

# %%
model=LogisticRegression(**grid_search.best_params_) 
model.fit(X_train,y_train)
prediction_train=model.predict(X_train)
prediction_test=model.predict(X_test)
print('The accuracy of the Logistic on train is',metrics.accuracy_score(prediction_train,y_train))
print('The accuracy of the Logistic on test is',metrics.accuracy_score(prediction_test,y_test))
# Out:
# The accuracy of the Logistic on train is 0.9732142857142857
# The accuracy of the Logistic on test is 1.0

# %%
print(classification_report(y_train, prediction_train))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        35
# Iris-versicolor       0.97      0.95      0.96        39
#  Iris-virginica       0.95      0.97      0.96        38
#
#       micro avg       0.97      0.97      0.97       112
#       macro avg       0.97      0.97      0.97       112
#    weighted avg       0.97      0.97      0.97       112
